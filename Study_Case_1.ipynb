# %% [markdown]
# <a href="https://colab.research.google.com/github/lidyaanggreni/DataMining_GroupG/blob/main/Study_Case_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings; warnings.simplefilter('ignore')
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, numpy as np
import matplotlib.cm as cm
from collections import Counter

try: # Running Locally, yakinkan "file_" berada di folder "data"
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')    
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/jakarta.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/depok.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bogor.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/tangerang.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bekasi.csv
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')
    
dfJ.shape, dfD.shape, dfB.shape, dfT.shape, dfX.shape
# Out:
# ((1024, 26), (998, 26), (999, 26), (128, 26), (992, 26))

# %%
import warnings; warnings.simplefilter('ignore')
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, numpy as np
import matplotlib.cm as cm
from collections import Counter
print(dfJ.duplicated().sum())
print(dfD.duplicated().sum())
print(dfB.duplicated().sum())
print(dfT.duplicated().sum())
print(dfX.duplicated().sum())
# Out:
# 902
# 877
# 805
# 3
# 884

# %%
print(dfJ.isnull().sum())
print(dfD.isnull().sum())
print(dfB.isnull().sum())
print(dfT.isnull().sum())
print(dfX.isnull().sum())
# Out:
# created_at      903
# LT              903
# LB              903
# KT              903
# KM              903
# garasi          980
# carport         934
# lokasi          903
# sertifikat      905
# listrik         904
# hadap           988
# harga           903
# URL             903
# deskripsi       912
# Unnamed: 14    1024
# Unnamed: 15    1024
# Unnamed: 16    1024
# Unnamed: 17    1024
# Unnamed: 18    1024
# Unnamed: 19    1024
# Unnamed: 20    1024
# Unnamed: 21    1024
# Unnamed: 22    1024
# Unnamed: 23    1024
# Unnamed: 24    1024
# Unnamed: 25    1024
# dtype: int64
# created_at     879
# LT             878
# LB             880
# KT             880
# KM             880
# garasi         973
# carport        904
# lokasi         880
# sertifikat     880
# listrik        895
# hadap          936
# harga          880
# URL            880
# deskripsi      880
# Unnamed: 14    998
# Unnamed: 15    998
# Unnamed: 16    998
# Unnamed: 17    998
# Unnamed: 18    998
# ...

# %%
dfJ.head()
# Out:
#    created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0  06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1  02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2  06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3  06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4  06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
#
#   sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 1        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 2        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 3        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4        SHM   2200.0  ...         NaN          NaN         NaN         NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# ...

# %%
dfJ.isna().sum()
# Out:
# created_at      903
# LT              903
# LB              903
# KT              903
# KM              903
# garasi          980
# carport         934
# lokasi          903
# sertifikat      905
# listrik         904
# hadap           988
# harga           903
# URL             903
# deskripsi       912
# Unnamed: 14    1024
# Unnamed: 15    1024
# Unnamed: 16    1024
# Unnamed: 17    1024
# Unnamed: 18    1024
# Unnamed: 19    1024
# Unnamed: 20    1024
# Unnamed: 21    1024
# Unnamed: 22    1024
# Unnamed: 23    1024
# Unnamed: 24    1024
# Unnamed: 25    1024
# dtype: int64

# %%
dfJ.describe()
# Out:
#                 LT           LB          KT          KM     garasi    carport  \
# count   121.000000   121.000000  121.000000  121.000000  44.000000  90.000000
# mean    247.586777   279.495868    4.272727    3.380165   1.863636   1.955556
# std     368.384642   285.275631    1.901754    1.709075   1.518734   1.475730
# min      16.000000    21.000000    1.000000    1.000000   1.000000   1.000000
# 25%      84.000000    97.000000    3.000000    2.000000   1.000000   1.000000
# 50%     135.000000   200.000000    4.000000    3.000000   1.000000   2.000000
# 75%     250.000000   350.000000    5.000000    4.000000   2.000000   2.000000
# max    3422.000000  2000.000000   10.000000   10.000000   8.000000  10.000000
#
#             listrik         harga  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# count    120.000000  1.210000e+02          0.0          0.0          0.0
# mean    5425.000000  8.985955e+09          NaN          NaN          NaN
# ...

# %% [markdown]
# **1. Kualitas data yang dimiliki perusahaan**
#
# Kualitas data perusahaan masih tergolong kurang baik karena terdapat beberapa kolom "unnamed" yang barisnya kosong sehingga kolom ini kita hapus karena tidak diperlukan serta terdapat banyak baris yang memiliki missing value. Selain itu, kami juga mengecek duplikat, noise, dan outlier dari data.

# %% [markdown]
# **2. Saran perbaikan data**
#
# Perusahaan dapat melakukan preprocessing terlebih dahulu terhadap data yang ada, seperti menghilangkan missing values dan duplicate

# %%
Jakarta = dfJ[['LT', 'LB', 'KT', 'KM','lokasi', 'sertifikat','hadap', 'garasi', 'carport', 'listrik', 'harga', 'URL', 'deskripsi']]
Jakarta
# Out:
#          LT     LB   KT   KM         lokasi sertifikat hadap  garasi  carport  \
# 0     202.0  198.0  8.0  3.0  Jakarta Pusat        SHM   NaN     NaN      NaN
# 1      30.0   55.0  2.0  1.0  Jakarta Pusat        SHM   NaN     NaN      1.0
# 2      19.0   35.0  2.0  1.0  Jakarta Pusat        SHM   NaN     NaN      NaN
# 3      33.0   42.0  2.0  2.0  Jakarta Pusat        SHM   NaN     NaN      1.0
# 4      30.0   55.0  2.0  2.0  Jakarta Pusat        SHM   NaN     NaN      1.0
# ...     ...    ...  ...  ...            ...        ...   ...     ...      ...
# 1019    NaN    NaN  NaN  NaN            NaN        NaN   NaN     NaN      NaN
# 1020    NaN    NaN  NaN  NaN            NaN        NaN   NaN     NaN      NaN
# 1021    NaN    NaN  NaN  NaN            NaN        NaN   NaN     NaN      NaN
# 1022    NaN    NaN  NaN  NaN            NaN        NaN   NaN     NaN      NaN
# 1023    NaN    NaN  NaN  NaN            NaN        NaN   NaN     NaN      NaN
#
#       listrik         harga  \
# ...

# %%
Jakarta.dropna(how = 'all', inplace = True)
Jakarta
# Out:
#         LT     LB   KT   KM         lokasi sertifikat    hadap  garasi  \
# 0    202.0  198.0  8.0  3.0  Jakarta Pusat        SHM      NaN     NaN
# 1     30.0   55.0  2.0  1.0  Jakarta Pusat        SHM      NaN     NaN
# 2     19.0   35.0  2.0  1.0  Jakarta Pusat        SHM      NaN     NaN
# 3     33.0   42.0  2.0  2.0  Jakarta Pusat        SHM      NaN     NaN
# 4     30.0   55.0  2.0  2.0  Jakarta Pusat        SHM      NaN     NaN
# ..     ...    ...  ...  ...            ...        ...      ...     ...
# 116  220.0  239.0  5.0  4.0  Jakarta Timur       PPJB      NaN     1.0
# 117   70.0   57.0  3.0  2.0  Jakarta Timur        SHM      NaN     NaN
# 118  315.0  280.0  4.0  3.0  Jakarta Timur  SHM + IMB    Timur     1.0
# 119  135.0  190.0  5.0  5.0  Jakarta Timur  SHM + IMB  Selatan     NaN
# 120  144.0  250.0  5.0  5.0  Jakarta Timur        SHM    Timur     NaN
#
#      carport  listrik         harga  \
# 0        NaN   2200.0  4.500000e+09
# 1        1.0   2200.0  1.100000e+09
# ...

# %%
Jakarta.plot(
   x='lokasi', 
   y='harga', 
   kind='scatter'
)

plt.show()

# %%
Depok = dfD[['LT', 'LB', 'KT', 'KM','lokasi', 'sertifikat','hadap', 'garasi', 'carport', 'listrik', 'harga', 'URL', 'deskripsi']]
Depok
# Out:
#       LT     LB   KT   KM     lokasi sertifikat    hadap  garasi  carport  \
# 0    165  200.0  4.0  2.0  Sukmajaya        SHM  Selatan     NaN      1.0
# 1     50   45.0  2.0  1.0   Cipayung        SHM      NaN     NaN      NaN
# 2     50   36.0  2.0  1.0   Sawangan        SHM    Barat     NaN      1.0
# 3     50   45.0  2.0  1.0  Cimanggis        SHM      NaN     NaN      NaN
# 4     72   45.0  2.0  1.0   Sawangan        SHM    Timur     NaN      1.0
# ..   ...    ...  ...  ...        ...        ...      ...     ...      ...
# 993  NaN    NaN  NaN  NaN        NaN        NaN      NaN     NaN      NaN
# 994  NaN    NaN  NaN  NaN        NaN        NaN      NaN     NaN      NaN
# 995  NaN    NaN  NaN  NaN        NaN        NaN      NaN     NaN      NaN
# 996  NaN    NaN  NaN  NaN        NaN        NaN      NaN     NaN      NaN
# 997  NaN    NaN  NaN  NaN        NaN        NaN      NaN     NaN      NaN
#
#      listrik   harga                                                URL  \
# ...

# %%
Depok.dropna(how = 'all', inplace = True)
Depok
# Out:
#                                                   LT     LB   KT   KM  \
# 0                                                165  200.0  4.0  2.0
# 1                                                 50   45.0  2.0  1.0
# 2                                                 50   36.0  2.0  1.0
# 3                                                 50   45.0  2.0  1.0
# 4                                                 72   45.0  2.0  1.0
# ..                                               ...    ...  ...  ...
# 115                                               40   40.0  2.0  1.0
# 116                                               50   50.0  2.0  1.0
# 117                                              100   15.0  3.0  3.0
# 120   - lokasi yang kami gunakan hanya per kecamatan    NaN  NaN  NaN
# 121  -harga yang kami gunakan adalah per satuan juta    NaN  NaN  NaN
#
#         lokasi sertifikat    hadap  garasi  carport  listrik   harga  \
# ...

# %%
Depok.plot(
   x='lokasi', 
   y='harga', 
   kind='scatter'
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-bba1403ed80e> in <module>
#       2    x='lokasi',
#       3    y='harga',
# ----> 4    kind='scatter'
#       5 )
#       6
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
# ...

# %%
Bogor = dfB[['LT', 'LB', 'KT', 'KM','lokasi', 'sertifikat','hadap', 'garasi', 'carport', 'listrik', 'harga', 'URL', 'deskripsi']]
Bogor
# Out:
#        LT    LB   KT   KM          lokasi sertifikat  hadap  garasi  carport  \
# 0    75.0  38.0  2.0  1.0      Bojonggede        SHM  Barat     1.0      1.0
# 1    60.0  40.0  1.0  1.0  Babakan Madang        SHM    NaN     0.0      1.0
# 2    60.0  50.0  2.0  2.0  Babakan Madang        SHM    NaN     0.0      1.0
# 3    60.0  70.0  3.0  2.0  Babakan Madang        SHM    NaN     0.0      1.0
# 4    90.0  60.0  3.0  2.0  Babakan Madang        SHM    NaN     0.0      2.0
# ..    ...   ...  ...  ...             ...        ...    ...     ...      ...
# 994   NaN   NaN  NaN  NaN             NaN        NaN    NaN     NaN      NaN
# 995   NaN   NaN  NaN  NaN             NaN        NaN    NaN     NaN      NaN
# 996   NaN   NaN  NaN  NaN             NaN        NaN    NaN     NaN      NaN
# 997   NaN   NaN  NaN  NaN             NaN        NaN    NaN     NaN      NaN
# 998   NaN   NaN  NaN  NaN             NaN        NaN    NaN     NaN      NaN
#
# ...

# %%
Bogor.dropna(how = 'all', inplace = True)
Bogor
# Out:
#         LT     LB   KT   KM          lokasi sertifikat  hadap  garasi  \
# 0     75.0   38.0  2.0  1.0      Bojonggede        SHM  Barat     1.0
# 1     60.0   40.0  1.0  1.0  Babakan Madang        SHM    NaN     0.0
# 2     60.0   50.0  2.0  2.0  Babakan Madang        SHM    NaN     0.0
# 3     60.0   70.0  3.0  2.0  Babakan Madang        SHM    NaN     0.0
# 4     90.0   60.0  3.0  2.0  Babakan Madang        SHM    NaN     0.0
# ..     ...    ...  ...  ...             ...        ...    ...     ...
# 188   90.0   36.0  2.0  1.0    Gunung Putri        SHM    NaN     0.0
# 189  107.0   31.0  2.0  1.0        Sukaraja        SHM    NaN     0.0
# 190  210.0  150.0  4.0  2.0   Bogor Selatan        SHM    NaN     1.0
# 191   90.0   36.0  2.0  1.0       Cileungsi        SHM    NaN     0.0
# 192   72.0   90.0  3.0  2.0        Cibinong        SHM    NaN     1.0
#
#      carport  listrik         harga  \
# 0        1.0   1300.0  6.925500e+08
# 1        1.0   2200.0  8.114000e+08
# ...

# %%
Bogor.plot(
   x='lokasi', 
   y='harga', 
   kind='scatter'
)

plt.show()

# %%
Tangerang = dfT[['LT', 'LB', 'KT', 'KM','lokasi', 'sertifikat','hadap', 'garasi', 'carport', 'listrik', 'harga', 'URL', 'deskripsi']]
Tangerang
# Out:
#         LT     LB   KT   KM                     lokasi sertifikat    hadap  \
# 0     60.0   50.0  3.0  2.0        BSD CITY, TANGERANG        SHM  Selatan
# 1     72.0   54.0  2.0  1.0          CISAUK, TANGERANG        SHM      NaN
# 2     60.0   48.0  3.0  2.0         CILEDUG, TANGERANG        SHM      NaN
# 3    200.0  225.0  5.0  4.0  LIPPO KARAWACI, TANGERANG        SHM      NaN
# 4     76.0  123.0  3.0  3.0     PONDOK CABE, TANGERANG        SHM      NaN
# ..     ...    ...  ...  ...                        ...        ...      ...
# 123   91.0   91.0  3.0  2.0           Poris, Tangerang        SHM      NaN
# 124    NaN    NaN  NaN  NaN                        NaN        NaN      NaN
# 125    NaN    NaN  NaN  NaN                        NaN        NaN      NaN
# 126    NaN    NaN  NaN  NaN                        NaN        NaN      NaN
# 127    NaN    NaN  NaN  NaN                        NaN        NaN      NaN
#
#      garasi  carport  listrik   harga  \
# ...

# %%
Tangerang.dropna(how = 'all', inplace = True)
Tangerang
# Out:
#         LT     LB   KT   KM                     lokasi  \
# 0     60.0   50.0  3.0  2.0        BSD CITY, TANGERANG
# 1     72.0   54.0  2.0  1.0          CISAUK, TANGERANG
# 2     60.0   48.0  3.0  2.0         CILEDUG, TANGERANG
# 3    200.0  225.0  5.0  4.0  LIPPO KARAWACI, TANGERANG
# 4     76.0  123.0  3.0  3.0     PONDOK CABE, TANGERANG
# ..     ...    ...  ...  ...                        ...
# 119   60.0   55.0  2.0  2.0  LIPPO KARAWACI, TANGERANG
# 120   66.0   70.0  3.0  2.0          Ciater, Tangerang
# 121  202.0   85.0  4.0  3.0  BSD Griya Loka, Tangerang
# 122  108.0  130.0  3.0  3.0      Pagedangan, Tangerang
# 123   91.0   91.0  3.0  2.0           Poris, Tangerang
#
#                           sertifikat    hadap  garasi  carport  listrik  \
# 0                                SHM  Selatan     NaN      NaN   1300.0
# 1                                SHM      NaN     1.0      1.0   1300.0
# 2                                SHM      NaN     2.0      2.0   2200.0
# ...

# %%
Tangerang.plot(
   x='lokasi', 
   y='harga', 
   kind='scatter'
)

plt.show()

# %%
Bekasi = dfX[['LT', 'LB', 'KT', 'KM','lokasi', 'sertifikat','hadap', 'garasi', 'carport', 'listrik', 'harga', 'URL', 'deskripsi']]
Bekasi
# Out:
#         LT     LB   KT   KM            lokasi sertifikat    hadap  garasi  \
# 0     71.0   43.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 1     59.0   60.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 2    124.0   95.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 3    144.0  100.0  2.0  1.0  Kabupaten Bekasi        SHM  Selatan     NaN
# 4    108.0  100.0  3.0  2.0  Kabupaten Bekasi        SHM    Timur     NaN
# ..     ...    ...  ...  ...               ...        ...      ...     ...
# 987    NaN    NaN  NaN  NaN               NaN        NaN      NaN     NaN
# 988    NaN    NaN  NaN  NaN               NaN        NaN      NaN     NaN
# 989    NaN    NaN  NaN  NaN               NaN        NaN      NaN     NaN
# 990    NaN    NaN  NaN  NaN               NaN        NaN      NaN     NaN
# 991    NaN    NaN  NaN  NaN               NaN        NaN      NaN     NaN
#
#      carport  listrik         harga  \
# 0        1.0   1300.0  5.500000e+08
# ...

# %%
Bekasi.dropna(how = 'all', inplace = True)
Bekasi
# Out:
#         LT     LB   KT   KM            lokasi sertifikat    hadap  garasi  \
# 0     71.0   43.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 1     59.0   60.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 2    124.0   95.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 3    144.0  100.0  2.0  1.0  Kabupaten Bekasi        SHM  Selatan     NaN
# 4    108.0  100.0  3.0  2.0  Kabupaten Bekasi        SHM    Timur     NaN
# ..     ...    ...  ...  ...               ...        ...      ...     ...
# 102  180.0  220.0  5.0  3.0       Kota Bekasi        SHM      NaN     NaN
# 103  140.0  250.0  3.0  2.0  Kabupaten Bekasi        SHM  Selatan     NaN
# 104   60.0   55.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 105   36.0   60.0  2.0  1.0  Kabupaten Bekasi        SHM    Timur     NaN
# 106   60.0   55.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
#
#      carport  listrik         harga  \
# 0        1.0   1300.0  5.500000e+08
# ...

# %%
Bekasi.plot(
   x='lokasi', 
   y='harga', 
   kind='scatter'
)

plt.show()

# %%
dfs = pd.concat([Jakarta,Depok,Bogor,Tangerang,Bekasi],ignore_index=True)
dfs
# Out:
#         LT     LB   KT   KM            lokasi sertifikat    hadap  garasi  \
# 0    202.0  198.0  8.0  3.0     Jakarta Pusat        SHM      NaN     NaN
# 1     30.0   55.0  2.0  1.0     Jakarta Pusat        SHM      NaN     NaN
# 2     19.0   35.0  2.0  1.0     Jakarta Pusat        SHM      NaN     NaN
# 3     33.0   42.0  2.0  2.0     Jakarta Pusat        SHM      NaN     NaN
# 4     30.0   55.0  2.0  2.0     Jakarta Pusat        SHM      NaN     NaN
# ..     ...    ...  ...  ...               ...        ...      ...     ...
# 660  180.0  220.0  5.0  3.0       Kota Bekasi        SHM      NaN     NaN
# 661  140.0  250.0  3.0  2.0  Kabupaten Bekasi        SHM  Selatan     NaN
# 662   60.0   55.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
# 663   36.0   60.0  2.0  1.0  Kabupaten Bekasi        SHM    Timur     NaN
# 664   60.0   55.0  2.0  1.0  Kabupaten Bekasi        SHM      NaN     NaN
#
#      carport  listrik         harga  \
# 0        NaN   2200.0  4.500000e+09
# ...

# %%
#Menghapus duplikat

dfs.drop_duplicates(inplace=True)
print(dfs.duplicated().sum())
print(dfs.shape)
# Out:
# 0
# (665, 13)

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 665 entries, 0 to 664
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LT          665 non-null    object
#  1   LB          663 non-null    float64
#  2   KT          663 non-null    float64
#  3   KM          662 non-null    float64
#  4   lokasi      663 non-null    object
#  5   sertifikat  658 non-null    object
#  6   hadap       214 non-null    object
#  7   garasi      333 non-null    float64
#  8   carport     550 non-null    float64
#  9   listrik     628 non-null    float64
#  10  harga       663 non-null    float64
#  11  URL         663 non-null    object
#  12  deskripsi   654 non-null    object
# dtypes: float64(7), object(6)
# memory usage: 72.7+ KB

# %%
dfs.head()
# Out:
#       LT     LB   KT   KM         lokasi sertifikat hadap  garasi  carport  \
# 0  202.0  198.0  8.0  3.0  Jakarta Pusat        SHM   NaN     NaN      NaN
# 1   30.0   55.0  2.0  1.0  Jakarta Pusat        SHM   NaN     NaN      1.0
# 2   19.0   35.0  2.0  1.0  Jakarta Pusat        SHM   NaN     NaN      NaN
# 3   33.0   42.0  2.0  2.0  Jakarta Pusat        SHM   NaN     NaN      1.0
# 4   30.0   55.0  2.0  2.0  Jakarta Pusat        SHM   NaN     NaN      1.0
#
#    listrik         harga                                                URL  \
# 0   2200.0  4.500000e+09  https://www.rumah.com/listing-properti/dijual-...
# 1   2200.0  1.100000e+09  https://www.rumah.com/listing-properti/dijual-...
# 2   2200.0  3.950000e+08  https://www.rumah.com/listing-properti/dijual-...
# 3   2200.0  8.350000e+08  https://www.rumah.com/listing-properti/dijual-...
# 4   2200.0  1.100000e+09  https://www.rumah.com/listing-properti/dijual-...
#
#                                            deskripsi
# ...

# %%
#Menghapus duplikat

Jakarta.drop_duplicates(inplace=True)
print(Jakarta.duplicated().sum())
print(Jakarta.shape)
# Out:
# 0
# (121, 13)

# %%
Depok.drop_duplicates(inplace=True)
print(Depok.duplicated().sum())
print(Depok.shape)
# Out:
# 0
# (120, 13)

# %%
Bogor.drop_duplicates(inplace=True)
print(Bogor.duplicated().sum())
print(Bogor.shape)
# Out:
# 0
# (193, 13)

# %%
Tangerang.drop_duplicates(inplace=True)
print(Tangerang.duplicated().sum())
print(Tangerang.shape)
# Out:
# 0
# (124, 13)

# %%
Bekasi.drop_duplicates(inplace=True)
print(Bekasi.duplicated().sum())
print(Bekasi.shape)
# Out:
# 0
# (107, 13)

# %%
print(Jakarta.mean())
print(Depok.mean())
print(Bogor.mean())
print(Tangerang.mean())
print(Bekasi.mean())
# Out:
# LT         2.475868e+02
# LB         2.794959e+02
# KT         4.272727e+00
# KM         3.380165e+00
# garasi     1.863636e+00
# carport    1.955556e+00
# listrik    5.425000e+03
# harga      8.985955e+09
# dtype: float64
# LB           92.618644
# KT            2.737288
# KM            1.940678
# garasi        1.760000
# carport       1.670213
# listrik    2147.572816
# harga      1194.440678
# dtype: float64
# LT         1.435751e+02
# LB         9.866321e+01
# KT         2.694301e+00
# KM         1.797927e+00
# garasi     1.554404e-01
# carport    1.310881e+00
# listrik    2.076166e+03
# harga      1.289362e+09
# dtype: float64
# LT          202.653226
# LB          199.491935
# KT            3.346774
# KM            2.693548
# garasi        2.210526
# carport       1.608696
# listrik    3962.162162
# harga      3849.556452
# dtype: float64
# LT         1.088224e+02
# LB         1.106355e+02
# KT         2.962617e+00
# KM         1.943396e+00
# garasi     1.090909e+00
# ...

# %% [markdown]
# **3. Kecenderungan Harga Rumah**
#
# Dilihat dari rata-rata tiap kota, diketahui bahwa rumah yang berada di Kota Depok memiliki harga terendah sedangkan rumah di Jakarta memiliki harga tertinggi

# %% [markdown]
# **4. Rekomendasi Kantor Cabang**
#
# Kami merekomendasikan untuk membuka kantor cabang di Kota Bogor karena dari data yang didapatkan, terlihat bahwa rumah yang paling banyak di jual berada di Bogor se

# %% [markdown]
# **5. Karakteristik Rumah yang Paling Banyak Dijual**
#
# Kami melihat bahwa karakteristik rumah yang paling banyak dijual adalah rumah dengan rasio perbandingan kamar tidur:kamar mandi = 2:1, serta rumah yang memiliki jumlah garasi 1.

# %% [markdown]
# **6. Rekomendasi rumah yang berpotensi menghasilkan keuntungan bagi perusahaan**
#
# Kami merekomendasikan rumah yang berada di Kota Depok karena rata-rata harga rumah di Kota Depok memiliki rata-rata harga rumah yang rendah di antara kota lainnya sehingga dapat menghasilkan keuntungan bagi perusahaan.

# %% [markdown]
# **7. Informasi lain**
#
# Informasi lain yang kami dapatkan dari data hanyalah
